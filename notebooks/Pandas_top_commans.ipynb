# %%
import pandas as pd

# %% [markdown]
# ## Чтение/Запись данных

# %%
df = pd.read_csv('file.csv') # чтение csv
df = dp.read_excel('file.xlsx') # чтение xlsx
df.to_csv('output.csv', index=False) # сохранение файла csv
df.to_excel('output.xlsx', index=False) # сохранение файла xlsx
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv('file.csv') # чтение csv
#       2 df = dp.read_excel('file.xlsx') # чтение xlsx
#       3 df.to_csv('output.csv', index=False) # сохранение файла csv
#
# File c:\Jupyter_notebook\PandasNumPyCourse\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Jupyter_notebook\PandasNumPyCourse\.venv\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Jupyter_notebook\PandasNumPyCourse\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Jupyter_notebook\PandasNumPyCourse\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Jupyter_notebook\PandasNumPyCourse\.venv\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file.csv'

# %% [markdown]
# ## Просмотр данных

# %%
df.head() # первые 5 строк
df.tail() # последние 5 строк
df.info() # информация о колонках
df.describe() # базовая статистика (mean, min, max)
df.shape() # размер (строки, колонки)
df.columns() # список колонок

# %% [markdown]
# ## Выбор данных

# %%
df['col'] # одна колонка
df[['col1', 'col2']] # несколько колонок 
df.iloc[0:5] # строки по индексу
df[df['col']>100] # фильтр по условию 
df[(df['col1']>10) & (df['col2']=='A')] # приемер из нескольких условий

# %% [markdown]
# ## Создание и изменение колонок

# %%
df['new'] = df['col1'] + df['col2']
df['new'] = df['col1'].apply(lambda x: x**2)

# %% [markdown]
# ## Агрегации

# %%
df['col'].sum()
df['col'].mean()
df['col'].max()
df['col'].min()
df.groupby('col1')['col2'].sum()
df.groupby('col1').agg({'col2':'sum','col3':'mean'})

# %% [markdown]
# ## Работа с пропусками

# %%
df.isnull().sum()
df.dropna()
df.fillna(0)
df['col'].fillna(df['col'].mean(), inplace=True)

# %% [markdown]
# ## Сортировка

# %%
df.sort_values('col', ascendong=False)
df.sort_values(['col1', 'col2'], ascending=[True, False])

# %% [markdown]
# ## Объеденение таблиц

# %%
df_merged = pd.merge(df1, df2, on='id', how='inner')
df_concat = pd.concat([df1, df2], axis=0)

# %% [markdown]
# ## Поворот таблиц

# %%
df.pivot_table(index='col1', columns='col2', values'col3', aggfunc='sum')

# %% [markdown]
# ## Уникальные значения

# %%
df['col'].unique()
df['col'].nunique()
df['col'].value_counts()

# %% [markdown]
# ## Преобразования типов

# %%
df['col'] = df['col'].astype(int)
df['col'] = pd.to_datetime(df['col'])

# %% [markdown]
# ## Работа с индексом

# %%
df.set_index('col', inplace=True)
df.reset_index(inplace=True)

# %% [markdown]
# ## Применение функций

# %%
df.applymap(lambda x: x*2)
df['col'].apply(lambda x: x**2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.applymap(lambda x: x*2)
#       2 df['col'].apply(lambda x: x**2)
#
# NameError: name 'df' is not defined
